# %% [markdown]
# # saindo da maldição

# %%
aula = "hello world"

# %%
print(aula)
# Out:
# hello world

# %%
aula
# Out:
# 'hello world'

# %%
#Entrada
lado = 4

# %%
#processamento
area = lado * lado

# %%
#saida
print("a área do quadrado é", area)
# Out:
# a área do quadrado é 16
